# %%
import pandas as pd
import pickle

import seaborn as sns 
import matplotlib.pyplot as plt 

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
# Setting up mlflow
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/1', creation_time=1667803369650, experiment_id='1', last_update_time=1667803369650, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715210102066

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","salekeen")

    mlflow.log_param("train-data-path","./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path","./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha",alpha)

    lr = Lasso(alpha=alpha)

    lr.fit(X_train,y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val,y_pred,squared=False)

    mlflow.log_metric("rmse",rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin",artifact_path="models_pickle")

# %% [markdown]
# ### Trying out Xgboost

# %%
import xgboost as xgb

# %%
from hyperopt import fmin,tpe,hp,STATUS_OK,Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train,label=y_train)
valid = xgb.DMatrix(X_val,label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals = 5,
    trials = Trials()
)
# Out:
# [13:07:28] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:6.87502
# [1]	validation-rmse:6.59297
# [2]	validation-rmse:6.56842
# [3]	validation-rmse:6.55854
# [4]	validation-rmse:6.55036
# [5]	validation-rmse:6.54451
# [6]	validation-rmse:6.53058
# [7]	validation-rmse:6.52762
# [8]	validation-rmse:6.51949
# [9]	validation-rmse:6.51440
# [10]	validation-rmse:6.50967
# [11]	validation-rmse:6.50160
# [12]	validation-rmse:6.49626
# [13]	validation-rmse:6.48805
# [14]	validation-rmse:6.48228
# [15]	validation-rmse:6.48085
# [16]	validation-rmse:6.47696
# [17]	validation-rmse:6.47011
# [18]	validation-rmse:6.46956
# [19]	validation-rmse:6.46764
# [20]	validation-rmse:6.46731
# [21]	validation-rmse:6.46412
# [22]	validation-rmse:6.46233
# [23]	validation-rmse:6.45902
# [24]	validation-rmse:6.46016
# [25]	validation-rmse:6.45879
# [26]	validation-rmse:6.45607
# [27]	validation-rmse:6.45671
# [28]	validation-rmse:6.45228
# [29]	validation-rmse:6.44972
# [30]	validation-rmse:6.44902
# [31]	validation-rmse:6.44844
# [32]	validation-rmse:6.44607
# [33]	validation-rmse:6.44531
# [34]	validation-rmse:6.44148
# [35]	validation-rmse:6.44539
# [36]	validation-rmse:6.44306
# [37]	validation-rmse:6.44159
# [38]	validation-rmse:6.44265
# [39]	validation-rmse:6.44078
# [40]	validation-rmse:6.43996
# [41]	validation-rmse:6.44499
# [42]	validation-rmse:6.44697
# [43]	validation-rmse:6.44552
# [44]	validation-rmse:6.44497
# [45]	validation-rmse:6.44273
# [46]	validation-rmse:6.43985
# [47]	validation-rmse:6.43744
# [48]	validation-rmse:6.43577
# [49]	validation-rmse:6.43886
# [50]	validation-rmse:6.43894
# [51]	validation-rmse:6.43796
# [52]	validation-rmse:6.43801
# [53]	validation-rmse:6.43625
# [54]	validation-rmse:6.43785
# [55]	validation-rmse:6.43893
# [56]	validation-rmse:6.43997
# [57]	validation-rmse:6.44014
# [58]	validation-rmse:6.44010
# [59]	validation-rmse:6.43882
# [60]	validation-rmse:6.43853
# [61]	validation-rmse:6.43994
# [62]	validation-rmse:6.43855
# [63]	validation-rmse:6.43826
# [64]	validation-rmse:6.43890
# [65]	validation-rmse:6.43893
# [66]	validation-rmse:6.43770
# [67]	validation-rmse:6.43906
# [68]	validation-rmse:6.43902
# [69]	validation-rmse:6.44013
# [70]	validation-rmse:6.43924
# [71]	validation-rmse:6.43972
# [72]	validation-rmse:6.44062
# [73]	validation-rmse:6.43963
# [74]	validation-rmse:6.44155
# [75]	validation-rmse:6.44321
# [76]	validation-rmse:6.44327
# [77]	validation-rmse:6.44376
# [78]	validation-rmse:6.44359
# [79]	validation-rmse:6.44652
# [80]	validation-rmse:6.44612
# [81]	validation-rmse:6.44773
# [82]	validation-rmse:6.44725
# [83]	validation-rmse:6.44731
# [84]	validation-rmse:6.44596
# [85]	validation-rmse:6.44687
# [86]	validation-rmse:6.44650
# [87]	validation-rmse:6.44304
# [88]	validation-rmse:6.44217
# [89]	validation-rmse:6.44473
# [90]	validation-rmse:6.44492
# [91]	validation-rmse:6.44622
# [92]	validation-rmse:6.44757
# [93]	validation-rmse:6.44885
# [94]	validation-rmse:6.45495
# [95]	validation-rmse:6.45698
# [96]	validation-rmse:6.45532
# [97]	validation-rmse:6.45569
# [98]	validation-rmse:6.45707
# [13:07:35] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.21187
# [1]	validation-rmse:19.28990
# [2]	validation-rmse:18.42408
# [3]	validation-rmse:17.61136
# [4]	validation-rmse:16.84912
# [5]	validation-rmse:16.13430
# [6]	validation-rmse:15.46472
# [7]	validation-rmse:14.83782
# [8]	validation-rmse:14.25145
# [9]	validation-rmse:13.70300
# [10]	validation-rmse:13.19087
# [11]	validation-rmse:12.71298
# [12]	validation-rmse:12.26703
# [13]	validation-rmse:11.85178
# [14]	validation-rmse:11.46525
# [15]	validation-rmse:11.10496
# [16]	validation-rmse:10.76996
# [17]	validation-rmse:10.45934
# [18]	validation-rmse:10.17066
# [19]	validation-rmse:9.90318
# [20]	validation-rmse:9.65544
# [21]	validation-rmse:9.42714
# [22]	validation-rmse:9.21524
# [23]	validation-rmse:9.01960
# [24]	validation-rmse:8.83881
# [25]	validation-rmse:8.67226
# [26]	validation-rmse:8.51937
# [27]	validation-rmse:8.37806
# [28]	validation-rmse:8.24757
# [29]	validation-rmse:8.12694
# [30]	validation-rmse:8.01590
# [31]	validation-rmse:7.91354
# [32]	validation-rmse:7.81928
# [33]	validation-rmse:7.73277
# [34]	validation-rmse:7.65307
# [35]	validation-rmse:7.57969
# [36]	validation-rmse:7.51278
# [37]	validation-rmse:7.45071
# [38]	validation-rmse:7.39341
# [39]	validation-rmse:7.34076
# [40]	validation-rmse:7.29187
# [41]	validation-rmse:7.24782
# [42]	validation-rmse:7.20574
# [43]	validation-rmse:7.16786
# [44]	validation-rmse:7.13218
# [45]	validation-rmse:7.09908
# [46]	validation-rmse:7.06919
# [47]	validation-rmse:7.04097
# [48]	validation-rmse:7.01563
# [49]	validation-rmse:6.99145
# [50]	validation-rmse:6.96897
# [51]	validation-rmse:6.94821
# [52]	validation-rmse:6.92904
# [53]	validation-rmse:6.91104
# [54]	validation-rmse:6.89448
# [55]	validation-rmse:6.87862
# [56]	validation-rmse:6.86399
# [57]	validation-rmse:6.85079
# [58]	validation-rmse:6.83865
# [59]	validation-rmse:6.82682
# [60]	validation-rmse:6.81624
# [61]	validation-rmse:6.80582
# [62]	validation-rmse:6.79653
# [63]	validation-rmse:6.78777
# [64]	validation-rmse:6.77921
# [65]	validation-rmse:6.77166
# [66]	validation-rmse:6.76432
# [67]	validation-rmse:6.75747
# [68]	validation-rmse:6.75069
# [69]	validation-rmse:6.74438
# [70]	validation-rmse:6.73835
# [71]	validation-rmse:6.73294
# [72]	validation-rmse:6.72772
# [73]	validation-rmse:6.72253
# [74]	validation-rmse:6.71758
# [75]	validation-rmse:6.71289
# [76]	validation-rmse:6.70835
# [77]	validation-rmse:6.70449
# [78]	validation-rmse:6.70097
# [79]	validation-rmse:6.69687
# [80]	validation-rmse:6.69374
# [81]	validation-rmse:6.69090
# [82]	validation-rmse:6.68763
# [83]	validation-rmse:6.68475
# [84]	validation-rmse:6.68204
# [85]	validation-rmse:6.67955
# [86]	validation-rmse:6.67698
# [87]	validation-rmse:6.67445
# [88]	validation-rmse:6.67228
# [89]	validation-rmse:6.67012
# [90]	validation-rmse:6.66836
# [91]	validation-rmse:6.66642
# [92]	validation-rmse:6.66459
# [93]	validation-rmse:6.66278
# [94]	validation-rmse:6.66115
# [95]	validation-rmse:6.65970
# [96]	validation-rmse:6.65836
# [97]	validation-rmse:6.65702
# [98]	validation-rmse:6.65572
# [99]	validation-rmse:6.65429
# [13:07:46] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.21147
# [1]	validation-rmse:19.28972
# [2]	validation-rmse:18.42492
# [3]	validation-rmse:17.61212
# [4]	validation-rmse:16.85028
# [5]	validation-rmse:16.13546
# [6]	validation-rmse:15.46577
# [7]	validation-rmse:14.83867
# [8]	validation-rmse:14.25398
# [9]	validation-rmse:13.70450
# [10]	validation-rmse:13.19025
# [11]	validation-rmse:12.71234
# [12]	validation-rmse:12.26582
# [13]	validation-rmse:11.85180
# [14]	validation-rmse:11.46323
# [15]	validation-rmse:11.10387
# [16]	validation-rmse:10.76801
# [17]	validation-rmse:10.45535
# [18]	validation-rmse:10.16597
# [19]	validation-rmse:9.89704
# [20]	validation-rmse:9.64795
# [21]	validation-rmse:9.41714
# [22]	validation-rmse:9.20513
# [23]	validation-rmse:9.00665
# [24]	validation-rmse:8.82531
# [25]	validation-rmse:8.65538
# [26]	validation-rmse:8.50013
# [27]	validation-rmse:8.35662
# [28]	validation-rmse:8.22361
# [29]	validation-rmse:8.10094
# [30]	validation-rmse:7.98791
# [31]	validation-rmse:7.88258
# [32]	validation-rmse:7.78666
# [33]	validation-rmse:7.69742
# [34]	validation-rmse:7.61660
# [35]	validation-rmse:7.54059
# [36]	validation-rmse:7.47019
# [37]	validation-rmse:7.40578
# [38]	validation-rmse:7.34685
# [39]	validation-rmse:7.29218
# [40]	validation-rmse:7.24104
# [41]	validation-rmse:7.19422
# [42]	validation-rmse:7.15178
# [43]	validation-rmse:7.11046
# [44]	validation-rmse:7.07398
# [45]	validation-rmse:7.04020
# [46]	validation-rmse:7.00899
# [47]	validation-rmse:6.97902
# [48]	validation-rmse:6.95168
# [49]	validation-rmse:6.92599
# [50]	validation-rmse:6.90227
# [51]	validation-rmse:6.88129
# [52]	validation-rmse:6.85995
# [53]	validation-rmse:6.84118
# [54]	validation-rmse:6.82308
# [55]	validation-rmse:6.80657
# [56]	validation-rmse:6.79121
# [57]	validation-rmse:6.77683
# [58]	validation-rmse:6.76351
# [59]	validation-rmse:6.75110
# [60]	validation-rmse:6.73923
# [61]	validation-rmse:6.72890
# [62]	validation-rmse:6.71852
# [63]	validation-rmse:6.70914
# [64]	validation-rmse:6.70034
# [65]	validation-rmse:6.69224
# [66]	validation-rmse:6.68470
# [67]	validation-rmse:6.67766
# [68]	validation-rmse:6.67043
# [69]	validation-rmse:6.66465
# [70]	validation-rmse:6.65823
# [71]	validation-rmse:6.65242
# [72]	validation-rmse:6.64726
# [73]	validation-rmse:6.64188
# [74]	validation-rmse:6.63690
# [75]	validation-rmse:6.63252
# [76]	validation-rmse:6.62840
# [77]	validation-rmse:6.62452
# [78]	validation-rmse:6.62049
# [79]	validation-rmse:6.61664
# [80]	validation-rmse:6.61307
# [81]	validation-rmse:6.61000
# [82]	validation-rmse:6.60735
# [83]	validation-rmse:6.60432
# [84]	validation-rmse:6.60186
# [85]	validation-rmse:6.59941
# [86]	validation-rmse:6.59692
# [87]	validation-rmse:6.59437
# [88]	validation-rmse:6.59218
# [89]	validation-rmse:6.59028
# [90]	validation-rmse:6.58827
# [91]	validation-rmse:6.58665
# [92]	validation-rmse:6.58480
# [93]	validation-rmse:6.58303
# [94]	validation-rmse:6.58164
# [95]	validation-rmse:6.57979
# [96]	validation-rmse:6.57823
# [97]	validation-rmse:6.57704
# [98]	validation-rmse:6.57574
# [99]	validation-rmse:6.57423
# [13:07:55] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.13799
# [1]	validation-rmse:7.04577
# [2]	validation-rmse:6.70556
# [3]	validation-rmse:6.62123
# [4]	validation-rmse:6.59185
# [5]	validation-rmse:6.58028
# [6]	validation-rmse:6.57051
# [7]	validation-rmse:6.56140
# [8]	validation-rmse:6.55807
# [9]	validation-rmse:6.55370
# [10]	validation-rmse:6.55013
# [11]	validation-rmse:6.54664
# [12]	validation-rmse:6.54436
# [13]	validation-rmse:6.54264
# [14]	validation-rmse:6.53811
# [15]	validation-rmse:6.53712
# [16]	validation-rmse:6.53631
# [17]	validation-rmse:6.53546
# [18]	validation-rmse:6.53525
# [19]	validation-rmse:6.53528
# [20]	validation-rmse:6.53450
# [21]	validation-rmse:6.53414
# [22]	validation-rmse:6.53313
# [23]	validation-rmse:6.53369
# [24]	validation-rmse:6.53229
# [25]	validation-rmse:6.53087
# [26]	validation-rmse:6.53699
# [27]	validation-rmse:6.53506
# [28]	validation-rmse:6.53590
# [29]	validation-rmse:6.53619
# [30]	validation-rmse:6.53524
# [31]	validation-rmse:6.53500
# [32]	validation-rmse:6.53442
# [33]	validation-rmse:6.53463
# [34]	validation-rmse:6.53514
# [35]	validation-rmse:6.53714
# [36]	validation-rmse:6.53712
# [37]	validation-rmse:6.53773
# [38]	validation-rmse:6.53583
# [39]	validation-rmse:6.53753
# [40]	validation-rmse:6.53787
# [41]	validation-rmse:6.53766
# [42]	validation-rmse:6.54096
# [43]	validation-rmse:6.54005
# [44]	validation-rmse:6.54015
# [45]	validation-rmse:6.54088
# [46]	validation-rmse:6.54151
# [47]	validation-rmse:6.54225
# [48]	validation-rmse:6.54178
# [49]	validation-rmse:6.54219
# [50]	validation-rmse:6.54204
# [51]	validation-rmse:6.54122
# [52]	validation-rmse:6.54249
# [53]	validation-rmse:6.54245
# [54]	validation-rmse:6.54267
# [55]	validation-rmse:6.54399
# [56]	validation-rmse:6.54438
# [57]	validation-rmse:6.54397
# [58]	validation-rmse:6.54721
# [59]	validation-rmse:6.54733
# [60]	validation-rmse:6.54783
# [61]	validation-rmse:6.54795
# [62]	validation-rmse:6.54769
# [63]	validation-rmse:6.54789
# [64]	validation-rmse:6.54763
# [65]	validation-rmse:6.54740
# [66]	validation-rmse:6.54985
# [67]	validation-rmse:6.55095
# [68]	validation-rmse:6.55222
# [69]	validation-rmse:6.55295
# [70]	validation-rmse:6.55330
# [71]	validation-rmse:6.55347
# [72]	validation-rmse:6.55368
# [73]	validation-rmse:6.55435
# [74]	validation-rmse:6.55435
# [75]	validation-rmse:6.55456
# [13:08:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:7.05560
# [1]	validation-rmse:6.68462
# [2]	validation-rmse:6.65607
# [3]	validation-rmse:6.64249
# [4]	validation-rmse:6.63303
# [5]	validation-rmse:6.62078
# [6]	validation-rmse:6.61154
# [7]	validation-rmse:6.60379
# [8]	validation-rmse:6.60049
# [9]	validation-rmse:6.59270
# [10]	validation-rmse:6.58652
# [11]	validation-rmse:6.58221
# [12]	validation-rmse:6.58301
# [13]	validation-rmse:6.57292
# [14]	validation-rmse:6.56957
# [15]	validation-rmse:6.57026
# [16]	validation-rmse:6.56707
# [17]	validation-rmse:6.56460
# [18]	validation-rmse:6.56299
# [19]	validation-rmse:6.56132
# [20]	validation-rmse:6.56111
# [21]	validation-rmse:6.55627
# [22]	validation-rmse:6.55219
# [23]	validation-rmse:6.55184
# [24]	validation-rmse:6.55335
# [25]	validation-rmse:6.54942
# [26]	validation-rmse:6.54655
# [27]	validation-rmse:6.54563
# [28]	validation-rmse:6.54647
# [29]	validation-rmse:6.54547
# [30]	validation-rmse:6.54476
# [31]	validation-rmse:6.55764
# [32]	validation-rmse:6.55853
# [33]	validation-rmse:6.55837
# [34]	validation-rmse:6.55733
# [35]	validation-rmse:6.55779
# [36]	validation-rmse:6.55658
# [37]	validation-rmse:6.55561
# [38]	validation-rmse:6.55388
# [39]	validation-rmse:6.55240
# [40]	validation-rmse:6.55156
# [41]	validation-rmse:6.55132
# [42]	validation-rmse:6.55213
# [43]	validation-rmse:6.55042
# [44]	validation-rmse:6.55316
# [45]	validation-rmse:6.55317
# [46]	validation-rmse:6.55290
# [47]	validation-rmse:6.55919
# [48]	validation-rmse:6.56225
# [49]	validation-rmse:6.56185
# [50]	validation-rmse:6.56246
# [51]	validation-rmse:6.56277
# [52]	validation-rmse:6.56107
# [53]	validation-rmse:6.56198
# [54]	validation-rmse:6.56431
# [55]	validation-rmse:6.56429
# [56]	validation-rmse:6.55906
# [57]	validation-rmse:6.55756
# [58]	validation-rmse:6.55824
# [59]	validation-rmse:6.55796
# [60]	validation-rmse:6.55946
# [61]	validation-rmse:6.56007
# [62]	validation-rmse:6.55926
# [63]	validation-rmse:6.56004
# [64]	validation-rmse:6.55940
# [65]	validation-rmse:6.56022
# [66]	validation-rmse:6.55894
# [67]	validation-rmse:6.55904
# [68]	validation-rmse:6.56061
# [69]	validation-rmse:6.56830
# [70]	validation-rmse:6.56948
# [71]	validation-rmse:6.57324
# [72]	validation-rmse:6.57485
# [73]	validation-rmse:6.57432
# [74]	validation-rmse:6.57551
# [75]	validation-rmse:6.58202
# [76]	validation-rmse:6.58224
# [77]	validation-rmse:6.58167
# [78]	validation-rmse:6.58203
# [79]	validation-rmse:6.58436
# 100%|██████████| 5/5 [00:44<00:00,  8.91s/trial, best loss: 6.457070338152139]

# %% [markdown]
# ### Logging Artifacts of the best model

# %%
with mlflow.start_run():
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path="models_mlflow")
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [13:25:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95635
# [2]	validation-rmse:16.59103
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29029
# [5]	validation-rmse:13.32807
# [6]	validation-rmse:12.47571
# [7]	validation-rmse:11.72138
# [8]	validation-rmse:11.05825
# [9]	validation-rmse:10.47535
# [10]	validation-rmse:9.96449
# [11]	validation-rmse:9.51756
# [12]	validation-rmse:9.12641
# [13]	validation-rmse:8.78569
# [14]	validation-rmse:8.49089
# [15]	validation-rmse:8.23445
# [16]	validation-rmse:8.01207
# [17]	validation-rmse:7.81886
# [18]	validation-rmse:7.65169
# [19]	validation-rmse:7.50672
# [20]	validation-rmse:7.38153
# [21]	validation-rmse:7.27299
# [22]	validation-rmse:7.17863
# [23]	validation-rmse:7.09718
# [24]	validation-rmse:7.02603
# [25]	validation-rmse:6.96344
# [26]	validation-rmse:6.90935
# [27]	validation-rmse:6.86285
# [28]	validation-rmse:6.82157
# [29]	validation-rmse:6.78486
# [30]	validation-rmse:6.75283
# [31]	validation-rmse:6.72433
# [32]	validation-rmse:6.69838
# [33]	validation-rmse:6.67599
# [34]	validation-rmse:6.65632
# [35]	validation-rmse:6.63968
# [36]	validation-rmse:6.62456
# [37]	validation-rmse:6.61030
# [38]	validation-rmse:6.59833
# [39]	validation-rmse:6.58671
# [40]	validation-rmse:6.57678
# [41]	validation-rmse:6.56792
# [42]	validation-rmse:6.56024
# [43]	validation-rmse:6.55307
# [44]	validation-rmse:6.54644
# [45]	validation-rmse:6.54087
# [46]	validation-rmse:6.53587
# [47]	validation-rmse:6.53128
# [48]	validation-rmse:6.52719
# [49]	validation-rmse:6.52427
# [50]	validation-rmse:6.52098
# [51]	validation-rmse:6.51875
# [52]	validation-rmse:6.51547
# [53]	validation-rmse:6.51333
# [54]	validation-rmse:6.51034
# [55]	validation-rmse:6.50826
# [56]	validation-rmse:6.50668
# [57]	validation-rmse:6.50477
# [58]	validation-rmse:6.50288
# [59]	validation-rmse:6.50114
# [60]	validation-rmse:6.49931
# [61]	validation-rmse:6.49758
# [62]	validation-rmse:6.49577
# [63]	validation-rmse:6.49364
# [64]	validation-rmse:6.49179
# [65]	validation-rmse:6.49031
# [66]	validation-rmse:6.48955
# [67]	validation-rmse:6.48814
# [68]	validation-rmse:6.48684
# [69]	validation-rmse:6.48526
# [70]	validation-rmse:6.48384
# [71]	validation-rmse:6.48249
# [72]	validation-rmse:6.48180
# [73]	validation-rmse:6.48127
# [74]	validation-rmse:6.48053
# [75]	validation-rmse:6.47965
# [76]	validation-rmse:6.47878
# [77]	validation-rmse:6.47808
# [78]	validation-rmse:6.47695
# [79]	validation-rmse:6.47605
# [80]	validation-rmse:6.47528
# [81]	validation-rmse:6.47416
# [82]	validation-rmse:6.47331
# [83]	validation-rmse:6.47237
# [84]	validation-rmse:6.47146
# [85]	validation-rmse:6.47022
# [86]	validation-rmse:6.46934
# [87]	validation-rmse:6.46830
# [88]	validation-rmse:6.46799
# [89]	validation-rmse:6.46740
# [90]	validation-rmse:6.46645
# [91]	validation-rmse:6.46556
# [92]	validation-rmse:6.46451
# [93]	validation-rmse:6.46355
# [94]	validation-rmse:6.46222
# [95]	validation-rmse:6.46134
# [96]	validation-rmse:6.46099
# [97]	validation-rmse:6.46062
# [98]	validation-rmse:6.46009
# [99]	validation-rmse:6.45985
# d:\Anaconda\envs\mlops\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# #### MLFLOW AUTOLOGGING

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import LinearSVR

# %%
mlflow.sklearn.autolog()
# Out:
# 2022/11/07 13:30:05 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.

# %%
for model_class in (RandomForestRegressor, GradientBoostingRegressor,
                    ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():
        mlflow.log_param("train-data-path",
                         "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path",
                         "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b",
                            artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\ML\MLOps-Zoomcamp\Part02-Experiment-Tracking\duration-prediction.ipynb Cell 24 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=8'>9</a> mlflow.log_artifact("models/preprocessor.b",
#      <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=9'>10</a>                     artifact_path="preprocessor")
#      <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=11'>12</a> mlmodel = model_class()
# ---> <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=12'>13</a> mlmodel.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=14'>15</a> y_pred = mlmodel.predict(X_val)
#      <a href='vscode-notebook-cell:/e%3A/ML/MLOps-Zoomcamp/Part02-Experiment-Tracking/duration-prediction.ipynb#X42sZmlsZQ%3D%3D?line=15'>16</a> rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:555, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     553     patch_function.call(call_original, *args, **kwargs)
#     554 else:
# --> 555     patch_function(call_original, *args, **kwargs)
#     557 session.state = "succeeded"
#     559 try_log_autologging_event(
#     560     AutologgingEventLogger.get_logger().log_patch_function_success,
#     561     session,
#    (...)
#     565     kwargs,
#     566 )
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:254, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     251     managed_run = create_managed_run()
#     253 try:
# --> 254     result = patch_function(original, *args, **kwargs)
#     255 except (Exception, KeyboardInterrupt):
#     256     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     257     # that runs are terminated if a user prematurely interrupts training execution
#     258     # (e.g. via sigint / ctrl-c)
#     259     if managed_run:
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\sklearn\__init__.py:1552, in _autolog.<locals>.patched_fit(fit_impl, original, self, *args, **kwargs)
#    1548 if t.should_log():
#    1549     # In `fit_mlflow` call, it will also call metric API for computing training metrics
#    1550     # so we need temporarily disable the post_training_metrics patching.
#    1551     with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1552         result = fit_impl(original, self, *args, **kwargs)
#    1553     if should_log_post_training_metrics:
#    1554         _AUTOLOGGING_METRICS_MANAGER.register_model(
#    1555             self, mlflow.active_run().info.run_id
#    1556         )
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\sklearn\__init__.py:1344, in _autolog.<locals>.fit_mlflow(original, self, *args, **kwargs)
#    1342 _log_pretraining_metadata(autologging_client, self, *args, **kwargs)
#    1343 params_logging_future = autologging_client.flush(synchronous=False)
# -> 1344 fit_output = original(self, *args, **kwargs)
#    1345 _log_posttraining_metadata(autologging_client, self, X, y_true, sample_weight)
#    1346 autologging_client.flush(synchronous=True)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:536, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     533         original_result = original(*_og_args, **_og_kwargs)
#     534         return original_result
# --> 536 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:471, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     462 try:
#     463     try_log_autologging_event(
#     464         AutologgingEventLogger.get_logger().log_original_function_start,
#     465         session,
#    (...)
#     469         og_kwargs,
#     470     )
# --> 471     original_fn_result = original_fn(*og_args, **og_kwargs)
#     473     try_log_autologging_event(
#     474         AutologgingEventLogger.get_logger().log_original_function_success,
#     475         session,
#    (...)
#     479         og_kwargs,
#     480     )
#     481     return original_fn_result
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:533, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     525 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     526 # during original function execution, even if silent mode is enabled
#     527 # (`silent=True`), since these warnings originate from the ML framework
#     528 # or one of its dependencies and are likely relevant to the caller
#     529 with set_non_mlflow_warnings_behavior_for_current_thread(
#     530     disable_warnings=False,
#     531     reroute_warnings=False,
#     532 ):
# --> 533     original_result = original(*_og_args, **_og_kwargs)
#     534     return original_result
#
# File d:\Anaconda\envs\mlops\lib\site-packages\sklearn\ensemble\_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File d:\Anaconda\envs\mlops\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File d:\Anaconda\envs\mlops\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:555, in safe_patch.<locals>.safe_patch_function(*args, **kwargs)
#     553     patch_function.call(call_original, *args, **kwargs)
#     554 else:
# --> 555     patch_function(call_original, *args, **kwargs)
#     557 session.state = "succeeded"
#     559 try_log_autologging_event(
#     560     AutologgingEventLogger.get_logger().log_patch_function_success,
#     561     session,
#    (...)
#     565     kwargs,
#     566 )
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:254, in with_managed_run.<locals>.patch_with_managed_run(original, *args, **kwargs)
#     251     managed_run = create_managed_run()
#     253 try:
# --> 254     result = patch_function(original, *args, **kwargs)
#     255 except (Exception, KeyboardInterrupt):
#     256     # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#     257     # that runs are terminated if a user prematurely interrupts training execution
#     258     # (e.g. via sigint / ctrl-c)
#     259     if managed_run:
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\sklearn\__init__.py:1559, in _autolog.<locals>.patched_fit(fit_impl, original, self, *args, **kwargs)
#    1557     return result
#    1558 else:
# -> 1559     return original(self, *args, **kwargs)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:536, in safe_patch.<locals>.safe_patch_function.<locals>.call_original(*og_args, **og_kwargs)
#     533         original_result = original(*_og_args, **_og_kwargs)
#     534         return original_result
# --> 536 return call_original_fn_with_event_logging(_original_fn, og_args, og_kwargs)
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:471, in safe_patch.<locals>.safe_patch_function.<locals>.call_original_fn_with_event_logging(original_fn, og_args, og_kwargs)
#     462 try:
#     463     try_log_autologging_event(
#     464         AutologgingEventLogger.get_logger().log_original_function_start,
#     465         session,
#    (...)
#     469         og_kwargs,
#     470     )
# --> 471     original_fn_result = original_fn(*og_args, **og_kwargs)
#     473     try_log_autologging_event(
#     474         AutologgingEventLogger.get_logger().log_original_function_success,
#     475         session,
#    (...)
#     479         og_kwargs,
#     480     )
#     481     return original_fn_result
#
# File d:\Anaconda\envs\mlops\lib\site-packages\mlflow\utils\autologging_utils\safety.py:533, in safe_patch.<locals>.safe_patch_function.<locals>.call_original.<locals>._original_fn(*_og_args, **_og_kwargs)
#     525 # Show all non-MLflow warnings as normal (i.e. not as event logs)
#     526 # during original function execution, even if silent mode is enabled
#     527 # (`silent=True`), since these warnings originate from the ML framework
#     528 # or one of its dependencies and are likely relevant to the caller
#     529 with set_non_mlflow_warnings_behavior_for_current_thread(
#     530     disable_warnings=False,
#     531     reroute_warnings=False,
#     532 ):
# --> 533     original_result = original(*_og_args, **_og_kwargs)
#     534     return original_result
#
# File d:\Anaconda\envs\mlops\lib\site-packages\sklearn\tree\_classes.py:1342, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1313 def fit(self, X, y, sample_weight=None, check_input=True):
#    1314     """Build a decision tree regressor from the training set (X, y).
#    1315
#    1316     Parameters
#    (...)
#    1339         Fitted estimator.
#    1340     """
# -> 1342     super().fit(
#    1343         X,
#    1344         y,
#    1345         sample_weight=sample_weight,
#    1346         check_input=check_input,
#    1347     )
#    1348     return self
#
# File d:\Anaconda\envs\mlops\lib\site-packages\sklearn\tree\_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
